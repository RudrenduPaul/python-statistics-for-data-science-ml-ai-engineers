# %% [markdown]
# # Tiny test 2

# %%
"""
A docstring here, multiple lines.
Second line of docstring.
"""

import os
import numpy as np

RNG = np.random.default_rng(42)

# %%
def save(fig, name):
    path = os.path.join("out", name + ".html")
    return path

# %%
fig0 = go.Figure()
fig0
# Out:
# fig

# %%
fig1 = go.Figure()
fig1
# Out:
# fig
